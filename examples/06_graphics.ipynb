# %% [markdown]
# # OpenOA graphics

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# The OpenOA toolkit includes a number of graphics that can be included in reports. This notebook demonstrates their usage.

# %% [markdown]
# ## Wind farm maps/layouts

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm
import pandas as pd
import copy

from project_ENGIE import Project_Engie

import operational_analysis.toolkits.pandas_plotting as tk_plots

from bokeh.plotting import show
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
# Load plant object
project = Project_Engie('./data/la_haute_borne')

# %%
# Prepare data
project.prepare()
# Out:
# INFO:project_ENGIE:Loading ASSET data
# INFO:project_ENGIE:ASSET data loaded
# INFO:project_ENGIE:Loading SCADA data
# INFO:operational_analysis.types.timeseries_table:Loading name:la-haute-borne-data-2014-2015
# INFO:project_ENGIE:SCADA data loaded
# INFO:project_ENGIE:Timestamp QC and conversion to UTC
# INFO:project_ENGIE:Correcting for out of range of temperature variables
# INFO:project_ENGIE:Flagging unresponsive sensors
# INFO:project_ENGIE:Converting field names to IEC 61400-25 standard
# INFO:operational_analysis.types.timeseries_table:Loading name:plant_data
# INFO:operational_analysis.types.timeseries_table:Loading name:plant_data
# INFO:operational_analysis.types.timeseries_table:Loading name:merra2_la_haute_borne
# INFO:operational_analysis.types.timeseries_table:Loading name:era5_wind_la_haute_borne

# %%
project.asset.prepare([1,2,3,4],None)

# %%
tk_plots.plot_array(project)

# %%
project.asset.df
# Out:
#    id      type Wind_turbine_name Wind_turbine_long_name Manufacturer Model  \
# 0   1   turbine            R80736        FRHBO_E04_80736      Senvion  MM82
# 1   2   turbine            R80721        FRHBO_E03_80721      Senvion  MM82
# 2   3   turbine            R80711        FRHBO_E01_80711      Senvion  MM82
# 3   4   turbine            R80790        FRHBO_E02_80790      Senvion  MM82
# 4   5  met mast             DUMMY           EXAMPLE_MAST          NaN   NaN
#
#    Rated power (kW)  Hub height (m)  Rotor diameter (m)  latitude  longitude  \
# 0            2050.0              80                82.0   48.4461     5.5925
# 1            2050.0              80                82.0   48.4497     5.5869
# 2            2050.0              80                82.0   48.4569     5.5847
# 3            2050.0              80                82.0   48.4536     5.5875
# 4               NaN              60                 NaN   48.4500     5.5800
#
#    Altitude (m) Commissioning date Department     Region  \
# 0           411         2009-01-15      Meuse  Grand Est
# 1           411         2009-01-15      Meuse  Grand Est
# 2           411         2009-01-15      Meuse  Grand Est
# 3           411         2009-01-15      Meuse  Grand Est
# 4           411         2009-01-15      Meuse  Grand Est
#
#                                       geometry nearest_turbine_id
# 0  POINT (691707.9356258927 5369131.008403569)                  2
# 1  POINT (691280.3372171954 5369517.101146103)                  4
# 2  POINT (691090.6427551308 5370311.819848928)                  4
# 3  POINT (691310.0390609576 5369952.051504722)                  3
# 4  POINT (690769.0548998963 5369533.217019108)               None

# %%
tk_plots.subplot_powerRose_array(project,turbine_ids=[1,2,3,4])

# %%
show(tk_plots.plot_windfarm(project))
# Out:
#   <div class="bk-root" id="26bc7c91-d9ed-4cf3-96ad-c0e5fc13f159" data-root-id="1006"></div>
